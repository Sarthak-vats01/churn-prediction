# %% [markdown]
# # Data Cleaning & Preprocessing
# ## ✅ EDA (Exploratory Data Analysis)
# ## ✅ Groupby, Pivot Tables
# ## ✅ Handling Dates & Time
# ## ✅ Feature Engineering
# ## ✅ SQL-style queries with pandas
# ## ✅ Visualizations with matplotlib/seaborn
# ## ✅ Report creation using Tableau
# ## ✅ Storytelling with Data
# ## ✅ Exporting Insights to CSV or PDF

# %% [markdown]
# # 🔍 Step 1: Data Cleaning & Basic Exploration

# %%
import pandas as pd

# %%
customers = pd.read_csv("customers.csv")
transactions = pd.read_csv("transactions.csv")

# %%
print(customers.head())
print(transactions.head())
# Out:
#   customer_id             name  age gender  income   join_date  credit_limit  \
# 0       C1000  Michael Charles   56  Other   35795  16-12-2020          5000
# 1       C1001     Ronald Boyle   46  Other  123694  18-06-2021         20000
# 2       C1002   Daniel Sanders   60   Male  139879  12-06-2022         10000
# 3       C1003      Billy Baker   38   Male   74886  23-11-2020         50000
# 4       C1004    Ryan Williams   36  Other  148214  17-10-2020         30000
#
#     status
# 0   Active
# 1   Active
# 2  Churned
# 3   Active
# 4   Active
#                          transaction_id customer_id transaction_date  amount  \
# 0  32d31488-bb51-41c6-9178-f773617d996f       C1080       22-03-2025    6.35
# 1  29143434-a9d1-4672-9ebb-3ac6cd524093       C1578       10-05-2023  214.48
# 2  ea841a3c-498a-42a8-9093-d3a577ddf7ad       C1700       14-11-2024   72.58
# 3  bc7a9d7c-6e3e-49cb-8bb9-a914bfe9add7       C1415       29-08-2023  236.99
# 4  c97d10ea-ad42-4307-8a38-63705a0fe7ed       C1487       03-05-2024   84.70
#
#         category                    merchant           city state  \
# 0  Entertainment             Cooper-Trujillo      East Ryan    MD
# 1       Shopping  White, Zimmerman and Munoz    Lake Alexis    UT
# 2         Travel            Fletcher-Webster    Bradleyview    MI
# 3     Healthcare                 Gould-Ortiz  Port Toddfort    KS
# 4         Dining             Nolan-Donaldson   West Brandon    AR
#
#   is_international card_type
# 0               No      Gold
# 1              Yes      Gold
# 2              Yes    Silver
# 3               No  Platinum
# 4              Yes  Platinum

# %%
print(customers.isnull().sum())
# Out:
# customer_id     0
# name            0
# age             0
# gender          0
# income          0
# join_date       0
# credit_limit    0
# status          0
# dtype: int64

# %%
print(transactions.isnull().sum())
# Out:
# transaction_id      0
# customer_id         0
# transaction_date    0
# amount              0
# category            0
# merchant            0
# city                0
# state               0
# is_international    0
# card_type           0
# dtype: int64

# %%
print(customers.dtypes)
print(transactions.dtypes)
# Out:
# customer_id     object
# name            object
# age              int64
# gender          object
# income           int64
# join_date       object
# credit_limit     int64
# status          object
# dtype: object
# transaction_id       object
# customer_id          object
# transaction_date     object
# amount              float64
# category             object
# merchant             object
# city                 object
# state                object
# is_international     object
# card_type            object
# dtype: object

# %%
customers['join_date'] = pd.to_datetime(customers['join_date'], dayfirst=True)

# %%
print(customers.dtypes)
# Out:
# customer_id             object
# name                    object
# age                      int64
# gender                  object
# income                   int64
# join_date       datetime64[ns]
# credit_limit             int64
# status                  object
# dtype: object

# %%
transactions['transaction_date'] = pd.to_datetime(transactions['transaction_date'], dayfirst = True)

# %% [markdown]
# # 📊 Step 2: Exploratory Data Analysis (EDA)

# %%
categorySpend = transactions.groupby('category')['amount'].sum().sort_values(ascending = True)

# %%
categorySpend
# Out:
# category
# Entertainment    115273.44
# Fuel             121890.80
# Utilities        123085.33
# Shopping         125608.72
# Groceries        126915.78
# Healthcare       127290.31
# Travel           127442.44
# Dining           127453.96
# Name: amount, dtype: float64

# %%
transactions['month'] = transactions['transaction_date'].dt.to_period('M')

# %%
monthly_spend = transactions.groupby('month')['amount'].sum().sort_values(ascending = True)

# %%
monthly_spend_Line = monthly_spend.plot(kind = 'line' , title = 'Monthly Spends')
monthly_spend_Line
# Out:
# <Axes: title={'center': 'Monthly Spends'}, xlabel='month'>

# %%
top_customers = transactions.groupby('customer_id')['amount'].sum().sort_values(ascending = False).head(7)
top_customers
# Out:
# customer_id
# C1830    2693.80
# C1549    2673.87
# C1265    2575.70
# C1049    2513.62
# C1554    2508.22
# C1825    2467.68
# C1237    2408.24
# Name: amount, dtype: float64

# %%
top_customer_name = top_customers.reset_index().merge(customers[['customer_id', 'name']], on = 'customer_id')
top_customer_name
# Out:
#   customer_id   amount              name
# 0       C1830  2693.80        Tonya Hess
# 1       C1549  2673.87   Timothy Bonilla
# 2       C1265  2575.70        Lisa Gates
# 3       C1049  2513.62     Michelle Carr
# 4       C1554  2508.22  Jamie Richardson
# 5       C1825  2467.68      Derek Conway
# 6       C1237  2408.24      Eric Jackson

# %% [markdown]
# # 🧠 Step 3: Feature Engineering

# %%
agg_data = transactions.groupby('customer_id').agg(
    total_spend=('amount','sum'),
    avg_spend= ('amount','mean'),
    txn_count=('amount','count'),
    int_txn_pct=('is_international', lambda x: (x== 'Yes').mean() * 100)
).reset_index()

agg_data
# Out:
#     customer_id  total_spend   avg_spend  txn_count  int_txn_pct
# 0         C1000       926.80  102.977778          9    44.444444
# 1         C1001      1015.18  101.518000         10    60.000000
# 2         C1002       644.10   71.566667          9    44.444444
# 3         C1003      1890.06  145.389231         13    38.461538
# 4         C1004      1149.96   95.830000         12    66.666667
# ..          ...          ...         ...        ...          ...
# 995       C1995      1322.94  101.764615         13    38.461538
# 996       C1996       912.03   82.911818         11    54.545455
# 997       C1997       589.94   42.138571         14    50.000000
# 998       C1998       948.19  105.354444          9    55.555556
# 999       C1999      1375.71   98.265000         14    35.714286
#
# [1000 rows x 5 columns]

# %%
customer_summary = pd.merge(customers, agg_data, on='customer_id')
customer_summary
# Out:
#     customer_id                name  age  gender  income  join_date  \
# 0         C1000     Michael Charles   56   Other   35795 2020-12-16
# 1         C1001        Ronald Boyle   46   Other  123694 2021-06-18
# 2         C1002      Daniel Sanders   60    Male  139879 2022-06-12
# 3         C1003         Billy Baker   38    Male   74886 2020-11-23
# 4         C1004       Ryan Williams   36   Other  148214 2020-10-17
# ..          ...                 ...  ...     ...     ...        ...
# 995       C1995         Sandra Gray   43   Other   61873 2024-07-09
# 996       C1996       Nicole Nelson   23    Male  126532 2025-02-16
# 997       C1997   Gerald Valenzuela   65    Male   23020 2023-05-31
# 998       C1998       Cynthia Barry   45   Other  105956 2021-12-09
# 999       C1999  Stephanie Roberson   30  Female   65648 2022-08-30
#
#      credit_limit    status  total_spend   avg_spend  txn_count  int_txn_pct
# 0            5000    Active       926.80  102.977778          9    44.444444
# 1           20000    Active      1015.18  101.518000         10    60.000000
# 2           10000   Churned       644.10   71.566667          9    44.444444
# 3           50000    Active      1890.06  145.389231         13    38.461538
# 4           30000    Active      1149.96   95.830000         12    66.666667
# ..            ...       ...          ...         ...        ...          ...
# 995         30000    Active      1322.94  101.764615         13    38.461538
# 996          5000   Churned       912.03   82.911818         11    54.545455
# 997         10000    Active       589.94   42.138571         14    50.000000
# 998         50000  Inactive       948.19  105.354444          9    55.555556
# 999         20000  Inactive      1375.71   98.265000         14    35.714286
#
# [1000 rows x 12 columns]

# %% [markdown]
# # 🔥 Step 4: Business Logic-Based Flags

# %%
def customerValue(t):
    if t >= 1000:
        return 'High'
    elif t > 500 and t < 1000:
        return 'Medium'
    else: 
        return 'Low'

customer_summary['value_segment'] = customer_summary['total_spend'].apply(customerValue)
customer_summary
# Out:
#     customer_id                name  age  gender  income  join_date  \
# 0         C1000     Michael Charles   56   Other   35795 2020-12-16
# 1         C1001        Ronald Boyle   46   Other  123694 2021-06-18
# 2         C1002      Daniel Sanders   60    Male  139879 2022-06-12
# 3         C1003         Billy Baker   38    Male   74886 2020-11-23
# 4         C1004       Ryan Williams   36   Other  148214 2020-10-17
# ..          ...                 ...  ...     ...     ...        ...
# 995       C1995         Sandra Gray   43   Other   61873 2024-07-09
# 996       C1996       Nicole Nelson   23    Male  126532 2025-02-16
# 997       C1997   Gerald Valenzuela   65    Male   23020 2023-05-31
# 998       C1998       Cynthia Barry   45   Other  105956 2021-12-09
# 999       C1999  Stephanie Roberson   30  Female   65648 2022-08-30
#
#      credit_limit    status  total_spend   avg_spend  txn_count  int_txn_pct  \
# 0            5000    Active       926.80  102.977778          9    44.444444
# 1           20000    Active      1015.18  101.518000         10    60.000000
# 2           10000   Churned       644.10   71.566667          9    44.444444
# 3           50000    Active      1890.06  145.389231         13    38.461538
# 4           30000    Active      1149.96   95.830000         12    66.666667
# ..            ...       ...          ...         ...        ...          ...
# 995         30000    Active      1322.94  101.764615         13    38.461538
# 996          5000   Churned       912.03   82.911818         11    54.545455
# 997         10000    Active       589.94   42.138571         14    50.000000
# 998         50000  Inactive       948.19  105.354444          9    55.555556
# 999         20000  Inactive      1375.71   98.265000         14    35.714286
#
#     value_segment
# 0          Medium
# 1            High
# 2          Medium
# 3            High
# 4            High
# ..            ...
# 995          High
# 996        Medium
# 997        Medium
# 998        Medium
# 999          High
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Category-wise Spends

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sortedSpend = categorySpend.sort_values(ascending = False)
colors = sns.color_palette('Set2', n_colors=len(sortedSpend))


plt.figure(figsize=(10,8))
sns.barplot(x= sortedSpend.index, y= sortedSpend.values, hue=sortedSpend.index, palette=colors)
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Total Spend By Category')
plt.xlabel('Category')
plt.ylabel('Spend')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Customer Segmentation

# %%
customer_summary['value_segment'].value_counts().plot.pie(autopct="%1.1f%%", startangle=90, title="Customer Segment", figsize=(6,6))

plt.show()

# %% [markdown]
# # International TXN Ratio

# %%
intRatio = transactions["is_international"].value_counts(normalize=True) * 100
colors = sns.color_palette('Set2', n_colors=len(intRatio))
intRatio.plot(kind='bar',title='Domestic vs International Txn', color=colors)
plt.grid(True)

# %% [markdown]
# # Customer Churn Prediction

# %%
churnThreshold = transactions['transaction_date'].max() - pd.DateOffset(months = 3)
churnThreshold
# Out:
# Timestamp('2025-01-19 00:00:00')

# %%
last_txn_per_customer = transactions.groupby('customer_id')['transaction_date'].max().reset_index()
last_txn_per_customer['churned'] = last_txn_per_customer['transaction_date'] > churnThreshold

# %%
last_txn_per_customer
# Out:
#     customer_id transaction_date  churned
# 0         C1000       2025-01-26     True
# 1         C1001       2025-02-18     True
# 2         C1002       2024-10-04    False
# 3         C1003       2025-04-01     True
# 4         C1004       2025-02-05     True
# ..          ...              ...      ...
# 995       C1995       2025-04-03     True
# 996       C1996       2024-10-28    False
# 997       C1997       2025-01-25     True
# 998       C1998       2025-04-19     True
# 999       C1999       2025-03-20     True
#
# [1000 rows x 3 columns]

# %%
customer_summary = customer_summary.merge(last_txn_per_customer[['customer_id','churned']], on='customer_id')
customer_summary
# Out:
#     customer_id                name  age  gender  income  join_date  \
# 0         C1000     Michael Charles   56   Other   35795 2020-12-16
# 1         C1001        Ronald Boyle   46   Other  123694 2021-06-18
# 2         C1002      Daniel Sanders   60    Male  139879 2022-06-12
# 3         C1003         Billy Baker   38    Male   74886 2020-11-23
# 4         C1004       Ryan Williams   36   Other  148214 2020-10-17
# ..          ...                 ...  ...     ...     ...        ...
# 995       C1995         Sandra Gray   43   Other   61873 2024-07-09
# 996       C1996       Nicole Nelson   23    Male  126532 2025-02-16
# 997       C1997   Gerald Valenzuela   65    Male   23020 2023-05-31
# 998       C1998       Cynthia Barry   45   Other  105956 2021-12-09
# 999       C1999  Stephanie Roberson   30  Female   65648 2022-08-30
#
#      credit_limit    status  total_spend   avg_spend  txn_count  int_txn_pct  \
# 0            5000    Active       926.80  102.977778          9    44.444444
# 1           20000    Active      1015.18  101.518000         10    60.000000
# 2           10000   Churned       644.10   71.566667          9    44.444444
# 3           50000    Active      1890.06  145.389231         13    38.461538
# 4           30000    Active      1149.96   95.830000         12    66.666667
# ..            ...       ...          ...         ...        ...          ...
# 995         30000    Active      1322.94  101.764615         13    38.461538
# 996          5000   Churned       912.03   82.911818         11    54.545455
# 997         10000    Active       589.94   42.138571         14    50.000000
# 998         50000  Inactive       948.19  105.354444          9    55.555556
# 999         20000  Inactive      1375.71   98.265000         14    35.714286
#
#     value_segment  churned
# 0          Medium     True
# 1            High     True
# 2          Medium    False
# 3            High     True
# 4            High     True
# ..            ...      ...
# 995          High     True
# 996        Medium    False
# 997        Medium     True
# 998        Medium     True
# 999          High     True
#
# [1000 rows x 14 columns]

# %%
from datetime import datetime

customer_summary['days_since_joining'] = (last_date - customer_summary['join_date']).dt.days

# %%
features = customer_summary[['total_spend', 'avg_spend', 'txn_count', 'int_txn_pct','days_since_joining']]
target = customer_summary['churned']


target , features
# Out:
# (0       True
#  1       True
#  2      False
#  3       True
#  4       True
#         ...
#  995     True
#  996    False
#  997     True
#  998     True
#  999     True
#  Name: churned, Length: 1000, dtype: bool,
#       total_spend   avg_spend  txn_count  int_txn_pct  days_since_joining
#  0         926.80  102.977778          9    44.444444                1585
#  1        1015.18  101.518000         10    60.000000                1401
#  2         644.10   71.566667          9    44.444444                1042
#  3        1890.06  145.389231         13    38.461538                1608
#  4        1149.96   95.830000         12    66.666667                1645
#  ..           ...         ...        ...          ...                 ...
#  995      1322.94  101.764615         13    38.461538                 284
#  996       912.03   82.911818         11    54.545455                  62
#  997       589.94   42.138571         14    50.000000                 689
#  998       948.19  105.354444          9    55.555556                1227
#  999      1375.71   98.265000         14    35.714286                 963
#
#  [1000 rows x 5 columns])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators = 100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)

print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 18  44]
#  [ 12 126]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.60      0.29      0.39        62
#         True       0.74      0.91      0.82       138
#
#     accuracy                           0.72       200
#    macro avg       0.67      0.60      0.60       200
# weighted avg       0.70      0.72      0.69       200

# %%
import matplotlib.pyplot as plt

feat_importance = pd.Series(model.feature_importances_, index=features.columns)
colors = sns.color_palette("Set2", n_colors= len(features.value_counts()))
feat_importance.sort_values().plot(kind='barh', title='Feature Importance', color = colors)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x=target, y = features['txn_count'])
plt.title('avg_spend V/s Churn')
plt.xlabel('Churned')
plt.ylabel('avg_spend')
plt.grid()
plt.show()
